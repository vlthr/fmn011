# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')

# %%
def bisection (func, a, b, tol=1e-12, max_iterations=50):
    iterations = 0
    left = a
    right = b
    
    while ((right - left)/2 > tol and iterations < max_iterations):
        iterations+=1
        c = (left + right)/2
        if (kfunc(c) * kfunc(left) > 0):
            left = c
        elif (kfunc(c) * kfunc(right) > 0):
            right = c
    
    c = (left + right)/2
    poss_err = (right - left)/2
    print("K=%.2f"%(c))
    #print("Possible error=%f"%poss_err)

# %%
bisec_func = lambda k: (10 + 1/(2*k))*np.e**(-k) - 7 - 1/(2*k)

# %%
xs = np.linspace(0.1,0.5,1000)
ys = bisec_func(xs)

bisection(bisec_func, 0.1, 0.5)

plt.plot(xs,ys)

plt.title("2a) ")
plt.xlabel("h (m)")
plt.ylabel("f (m)")
plt.show()
# Out:
# K=0.30
# Possible error=0.000000

# %%
def fixed_point (func ,start_p, tol=1e-12, max_itr=1000):
    iterations = 0
    p = start_p
    while (np.abs(p - func(p)) > tol and iterations < max_itr):
        iterations+=1
        p = func(p)
    
    print(p)
    print(iterations)

# %%
fixed_func = lambda k: k/7*(10 + 1/(2*k))*np.e**(-k) - 1 /14

# %%
fixed_func2 = lambda k: ((10 + 1/(2*k))*np.e**(-k)*k-1/2)/7

# %%
y_equals_x = lambda x: x

# %%
xs = np.linspace(0.27,0.33,1000)
ys = fixed_func2(xs)

y1 = y_equals_x(xs)

plt.plot(xs,ys)
plt.plot(xs, y1)

fixed_point(fixed_func2, 4)

plt.title("2a) ")
plt.xlabel("h (m)")
plt.ylabel("f (m)")
plt.show()
# Out:
# 0.29670305321201396
# 77

# %%
death_func = lambda t: 22 + 0.5*t - 1/(2*0.29670305) + (10 + 1/(2*t))*np.e**(-0.29670305*t)

# %%
y37_func = lambda y: 37

# %%
xs = np.linspace(-2.2,-1.5,1000)
ys = death_func(xs)

plt.plot(xs,ys)

plt.title("2a) ")
plt.xlabel("h (m)")
plt.ylabel("f (m)")
plt.show()
